# %%
import pandas as pd

df = pd.DataFrame({
    "Order_ID": [101,102,103,104,105,106,107,108,109,110,
                 111,112,113,114,115,116,117,118,119,120],

    "Order_DateTime": [
        "2025-01-05 09:15:30",
        "2025-01-12 14:45:20",
        "2025-02-03 11:20:10",
        "2025-02-18 16:35:45",
        "2025-03-07 10:05:25",
        "2025-03-25 18:50:40",
        "2025-04-10 08:30:15",
        "2025-04-22 13:40:55",
        "2025-05-05 17:10:35",
        "2025-05-28 12:25:50",
        "2025-06-11 15:45:05",
        "2025-06-30 19:20:30",
        "2025-07-04 09:55:15",
        "2025-07-19 11:15:40",
        "2025-08-08 14:05:25",
        "2025-08-26 16:50:10",
        "2025-09-09 10:40:20",
        "2025-10-14 18:30:45",
        "2025-11-21 13:15:35",
        "2025-12-30 20:10:50"
    ],

    "Customer": [
        "Rohit","Virat","Dhoni","Rahul","Hardik",
        "Gill","Ishan","Pant","Surya","Bumrah",
        "KL Rahul","Jadeja","Ashwin","Shami","Siraj",
        "Axar","Kuldeep","Arshdeep","Rinku","Tilak"
    ],

    "City": [
        "Delhi","Mumbai","Chennai","Lucknow","Pune",
        "Ahmedabad","Kolkata","Jaipur","Hyderabad","Delhi",
        "Mumbai","Chennai","Lucknow","Pune","Ahmedabad",
        "Kolkata","Hyderabad","Jaipur","Delhi","Mumbai"
    ],

    "Product": [
        "Laptop","Mobile","Tablet","Headphones","Keyboard",
        "Mouse","Monitor","Printer","Camera","Laptop",
        "Mobile","Tablet","Keyboard","Mouse","Monitor",
        "Printer","Camera","Laptop","Tablet","Mobile"
    ],

    "Sales": [
        65000,25000,18000,2500,1800,
        900,15000,12000,45000,70000,
        28000,20000,2200,1000,17000,
        14000,48000,72000,21000,30000
    ]
})

# Convert to DateTime
df["Order_DateTime"] = pd.to_datetime(df["Order_DateTime"])

print(df)
# Out:
#     Order_ID      Order_DateTime  Customer       City     Product  Sales
# 0        101 2025-01-05 09:15:30     Rohit      Delhi      Laptop  65000
# 1        102 2025-01-12 14:45:20     Virat     Mumbai      Mobile  25000
# 2        103 2025-02-03 11:20:10     Dhoni    Chennai      Tablet  18000
# 3        104 2025-02-18 16:35:45     Rahul    Lucknow  Headphones   2500
# 4        105 2025-03-07 10:05:25    Hardik       Pune    Keyboard   1800
# 5        106 2025-03-25 18:50:40      Gill  Ahmedabad       Mouse    900
# 6        107 2025-04-10 08:30:15     Ishan    Kolkata     Monitor  15000
# 7        108 2025-04-22 13:40:55      Pant     Jaipur     Printer  12000
# 8        109 2025-05-05 17:10:35     Surya  Hyderabad      Camera  45000
# 9        110 2025-05-28 12:25:50    Bumrah      Delhi      Laptop  70000
# 10       111 2025-06-11 15:45:05  KL Rahul     Mumbai      Mobile  28000
# 11       112 2025-06-30 19:20:30    Jadeja    Chennai      Tablet  20000
# ...

# %%
# 1. Convert to lowercase
print(df["Customer"].str.lower())
# Out:
# 0        rohit
# 1        virat
# 2        dhoni
# 3        rahul
# 4       hardik
# 5         gill
# 6        ishan
# 7         pant
# 8        surya
# 9       bumrah
# 10    kl rahul
# 11      jadeja
# 12      ashwin
# 13       shami
# 14       siraj
# 15        axar
# 16     kuldeep
# 17    arshdeep
# 18       rinku
# 19       tilak
# Name: Customer, dtype: object

# %%
# 2. Convert Customer to uppercase
print(df["Customer"].str.upper())
# Out:
# 0        ROHIT
# 1        VIRAT
# 2        DHONI
# 3        RAHUL
# 4       HARDIK
# 5         GILL
# 6        ISHAN
# 7         PANT
# 8        SURYA
# 9       BUMRAH
# 10    KL RAHUL
# 11      JADEJA
# 12      ASHWIN
# 13       SHAMI
# 14       SIRAJ
# 15        AXAR
# 16     KULDEEP
# 17    ARSHDEEP
# 18       RINKU
# 19       TILAK
# Name: Customer, dtype: object

# %%
# 3. Convert Customer to Title Case
print(df["Customer"].str.title())
# Out:
# 0        Rohit
# 1        Virat
# 2        Dhoni
# 3        Rahul
# 4       Hardik
# 5         Gill
# 6        Ishan
# 7         Pant
# 8        Surya
# 9       Bumrah
# 10    Kl Rahul
# 11      Jadeja
# 12      Ashwin
# 13       Shami
# 14       Siraj
# 15        Axar
# 16     Kuldeep
# 17    Arshdeep
# 18       Rinku
# 19       Tilak
# Name: Customer, dtype: object

# %%
# 4. Remove spaces from both sides
print(df["Customer"].str.strip())
# Out:
# 0        Rohit
# 1        Virat
# 2        Dhoni
# 3        Rahul
# 4       Hardik
# 5         Gill
# 6        Ishan
# 7         Pant
# 8        Surya
# 9       Bumrah
# 10    KL Rahul
# 11      Jadeja
# 12      Ashwin
# 13       Shami
# 14       Siraj
# 15        Axar
# 16     Kuldeep
# 17    Arshdeep
# 18       Rinku
# 19       Tilak
# Name: Customer, dtype: object

# %%
# 4. Remove spaces from both sides
print(df["Customer"].str.strip())
# Out:
# 0        Rohit
# 1        Virat
# 2        Dhoni
# 3        Rahul
# 4       Hardik
# 5         Gill
# 6        Ishan
# 7         Pant
# 8        Surya
# 9       Bumrah
# 10    KL Rahul
# 11      Jadeja
# 12      Ashwin
# 13       Shami
# 14       Siraj
# 15        Axar
# 16     Kuldeep
# 17    Arshdeep
# 18       Rinku
# 19       Tilak
# Name: Customer, dtype: object

# %%
# 5. Remove left spaces
print(df["Customer"].str.lstrip())
# Out:
# 0        Rohit
# 1        Virat
# 2        Dhoni
# 3        Rahul
# 4       Hardik
# 5         Gill
# 6        Ishan
# 7         Pant
# 8        Surya
# 9       Bumrah
# 10    KL Rahul
# 11      Jadeja
# 12      Ashwin
# 13       Shami
# 14       Siraj
# 15        Axar
# 16     Kuldeep
# 17    Arshdeep
# 18       Rinku
# 19       Tilak
# Name: Customer, dtype: object

# %%
# 6. Remove right spaces
print(df["Customer"].str.rstrip())
# Out:
# 0        Rohit
# 1        Virat
# 2        Dhoni
# 3        Rahul
# 4       Hardik
# 5         Gill
# 6        Ishan
# 7         Pant
# 8        Surya
# 9       Bumrah
# 10    KL Rahul
# 11      Jadeja
# 12      Ashwin
# 13       Shami
# 14       Siraj
# 15        Axar
# 16     Kuldeep
# 17    Arshdeep
# 18       Rinku
# 19       Tilak
# Name: Customer, dtype: object

# %%
# 7. Length of Customer name
print(df["Customer"].str.len())
# Out:
# 0     5
# 1     5
# 2     5
# 3     5
# 4     6
# 5     4
# 6     5
# 7     4
# 8     5
# 9     6
# 10    8
# 11    6
# 12    6
# 13    5
# 14    5
# 15    4
# 16    7
# 17    8
# 18    5
# 19    5
# Name: Customer, dtype: int64

# %%
# 8. Replace text
print(df["City"].str.replace("Delhi", "New Delhi"))
# Out:
# 0     New Delhi
# 1        Mumbai
# 2       Chennai
# 3       Lucknow
# 4          Pune
# 5     Ahmedabad
# 6       Kolkata
# 7        Jaipur
# 8     Hyderabad
# 9     New Delhi
# 10       Mumbai
# 11      Chennai
# 12      Lucknow
# 13         Pune
# 14    Ahmedabad
# 15      Kolkata
# 16    Hyderabad
# 17       Jaipur
# 18    New Delhi
# 19       Mumbai
# Name: City, dtype: object

# %%
# 9. Search text
print(df["Customer"].str.contains("Rahul"))
# Out:
# 0     False
# 1     False
# 2     False
# 3      True
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10     True
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# Name: Customer, dtype: bool

# %%
# 10. Starts with
print(df["Customer"].str.startswith("R"))
# Out:
# 0      True
# 1     False
# 2     False
# 3      True
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18     True
# 19    False
# Name: Customer, dtype: bool

# %%
# 11. Ends with
print(df["Customer"].str.endswith("a"))
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8      True
# 9     False
# 10    False
# 11     True
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# Name: Customer, dtype: bool

# %%
# 12. Count occurrence of letter 'a'
print(df["Customer"].str.count("a"))
# Out:
# 0     0
# 1     1
# 2     0
# 3     1
# 4     1
# 5     0
# 6     1
# 7     1
# 8     1
# 9     1
# 10    1
# 11    2
# 12    0
# 13    1
# 14    1
# 15    1
# 16    0
# 17    0
# 18    0
# 19    1
# Name: Customer, dtype: int64

# %%
# 13. Find first occurrence of "Rahul"
print(df["Customer"].str.find("Rahul"))
# Out:
# 0    -1
# 1    -1
# 2    -1
# 3     0
# 4    -1
# 5    -1
# 6    -1
# 7    -1
# 8    -1
# 9    -1
# 10    3
# 11   -1
# 12   -1
# 13   -1
# 14   -1
# 15   -1
# 16   -1
# 17   -1
# 18   -1
# 19   -1
# Name: Customer, dtype: int64

# %%
# 14. Split Customer name
print(df["Customer"].str.split(" "))
# Out:
# 0         [Rohit]
# 1         [Virat]
# 2         [Dhoni]
# 3         [Rahul]
# 4        [Hardik]
# 5          [Gill]
# 6         [Ishan]
# 7          [Pant]
# 8         [Surya]
# 9        [Bumrah]
# 10    [KL, Rahul]
# 11       [Jadeja]
# 12       [Ashwin]
# 13        [Shami]
# 14        [Siraj]
# 15         [Axar]
# 16      [Kuldeep]
# 17     [Arshdeep]
# 18        [Rinku]
# 19        [Tilak]
# Name: Customer, dtype: object

# %%
# 15. Split from right
print(df["Customer"].str.rsplit(" ", n=1))
# Out:
# 0         [Rohit]
# 1         [Virat]
# 2         [Dhoni]
# 3         [Rahul]
# 4        [Hardik]
# 5          [Gill]
# 6         [Ishan]
# 7          [Pant]
# 8         [Surya]
# 9        [Bumrah]
# 10    [KL, Rahul]
# 11       [Jadeja]
# 12       [Ashwin]
# 13        [Shami]
# 14        [Siraj]
# 15         [Axar]
# 16      [Kuldeep]
# 17     [Arshdeep]
# 18        [Rinku]
# 19        [Tilak]
# Name: Customer, dtype: object

# %%
# 16. Join Customer and City
print(df["Customer"].str.cat(df["City"], sep=" - "))
# Out:
# 0           Rohit - Delhi
# 1          Virat - Mumbai
# 2         Dhoni - Chennai
# 3         Rahul - Lucknow
# 4           Hardik - Pune
# 5        Gill - Ahmedabad
# 6         Ishan - Kolkata
# 7           Pant - Jaipur
# 8       Surya - Hyderabad
# 9          Bumrah - Delhi
# 10      KL Rahul - Mumbai
# 11       Jadeja - Chennai
# 12       Ashwin - Lucknow
# 13           Shami - Pune
# 14      Siraj - Ahmedabad
# 15         Axar - Kolkata
# 16    Kuldeep - Hyderabad
# 17      Arshdeep - Jaipur
# 18          Rinku - Delhi
# 19         Tilak - Mumbai
# Name: Customer, dtype: object

# %%
# 17. Check only letters
print(df["Product"].str.isalpha())
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# 14    True
# 15    True
# 16    True
# 17    True
# 18    True
# 19    True
# Name: Product, dtype: bool

# %%
# 18. Check only digits
print(df["Order_ID"].astype(str).str.isdigit())
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# 14    True
# 15    True
# 16    True
# 17    True
# 18    True
# 19    True
# Name: Order_ID, dtype: bool

# %%
# 19. Check letters and digits
print(df["Product"].str.isalnum())
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# 14    True
# 15    True
# 16    True
# 17    True
# 18    True
# 19    True
# Name: Product, dtype: bool

# %%
# 20. Check lowercase
print(df["Customer"].str.islower())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# Name: Customer, dtype: bool

# %%
# 21. Check uppercase
print(df["Customer"].str.isupper())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# Name: Customer, dtype: bool

# %%
#Find all regex matches 
print(df["Product"].str.extract(r"(\w+)"))
# Out:
#              0
# 0       Laptop
# 1       Mobile
# 2       Tablet
# 3   Headphones
# 4     Keyboard
# 5        Mouse
# 6      Monitor
# 7      Printer
# 8       Camera
# 9       Laptop
# 10      Mobile
# 11      Tablet
# 12    Keyboard
# 13       Mouse
# 14     Monitor
# 15     Printer
# 16      Camera
# 17      Laptop
# 18      Tablet
# 19      Mobile

# %%
print(df["Product"].str.findall(r"\w+"))
# Out:
# 0         [Laptop]
# 1         [Mobile]
# 2         [Tablet]
# 3     [Headphones]
# 4       [Keyboard]
# 5          [Mouse]
# 6        [Monitor]
# 7        [Printer]
# 8         [Camera]
# 9         [Laptop]
# 10        [Mobile]
# 11        [Tablet]
# 12      [Keyboard]
# 13         [Mouse]
# 14       [Monitor]
# 15       [Printer]
# 16        [Camera]
# 17        [Laptop]
# 18        [Tablet]
# 19        [Mobile]
# Name: Product, dtype: object

# %%
print(df["Customer"].str.slice(0,5))
# Out:
# 0     Rohit
# 1     Virat
# 2     Dhoni
# 3     Rahul
# 4     Hardi
# 5      Gill
# 6     Ishan
# 7      Pant
# 8     Surya
# 9     Bumra
# 10    KL Ra
# 11    Jadej
# 12    Ashwi
# 13    Shami
# 14    Siraj
# 15     Axar
# 16    Kulde
# 17    Arshd
# 18    Rinku
# 19    Tilak
# Name: Customer, dtype: object

# %%
print(df["Order_ID"].astype(str).str.zfill(5))
# Out:
# 0     00101
# 1     00102
# 2     00103
# 3     00104
# 4     00105
# 5     00106
# 6     00107
# 7     00108
# 8     00109
# 9     00110
# 10    00111
# 11    00112
# 12    00113
# 13    00114
# 14    00115
# 15    00116
# 16    00117
# 17    00118
# 18    00119
# 19    00120
# Name: Order_ID, dtype: object

# %%
print(df["Customer"].str.get(0))
# Out:
# 0     R
# 1     V
# 2     D
# 3     R
# 4     H
# 5     G
# 6     I
# 7     P
# 8     S
# 9     B
# 10    K
# 11    J
# 12    A
# 13    S
# 14    S
# 15    A
# 16    K
# 17    A
# 18    R
# 19    T
# Name: Customer, dtype: object
