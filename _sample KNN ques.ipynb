# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder
import pandas as pd
import streamlit as st
from sklearn.linear_model import LinearRegression
import pickle
data = pd.read_csv("Sample-Superstore.csv",encoding="latin1")
df=pd.DataFrame(data)
print(df)
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.tail()
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 9989    9990  CA-2014-110422  1/21/2014  1/23/2014    Second Class
# 9990    9991  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9991    9992  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9992    9993  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9993    9994  CA-2017-119914   5/4/2017   5/9/2017    Second Class
#
#      Customer ID     Customer Name   Segment        Country         City  ...  \
# 9989    TB-21400  Tom Boeckenhauer  Consumer  United States        Miami  ...
# 9990    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9991    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9992    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9993    CC-12220      Chris Cortes  Consumer  United States  Westminster  ...
#
#      Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
print(df.isnull().sum())
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
df.dtypes
# Out:
# Row ID             int64
# Order ID          object
# Order Date        object
# Ship Date         object
# Ship Mode         object
# Customer ID       object
# Customer Name     object
# Segment           object
# Country           object
# City              object
# State             object
# Postal Code        int64
# Region            object
# Product ID        object
# Category          object
# Sub-Category      object
# Product Name      object
# Sales            float64
# Quantity           int64
# Discount         float64
# Profit           float64
# dtype: object

# %%
# 1. How many total orders are present in the dataset?
# 2. How many unique customers are there?
# 3. Which state has the highest sales?
# 4. Which city generated the maximum profit?
# 5. Which category has the highest total sales?
# 6. Which sub-category has the highest profit?
# 7. Which ship mode is used most frequently?
# 8. Which customer placed the highest number of orders?
# 9. Which segment contributes the highest sales?
# 10. What is the total sales and total profit?
# 11. Which region has the maximum profit?
# 12. Find the average sales per order.
# 13. Which product has the highest sales?
# 14. Which product has the highest profit?
# 15. Which state has the highest loss?
# 16. Which sub-category has the lowest profit?
# 17. What is the monthly sales trend?
# 18. What is the yearly profit trend?
# 19. Which month has the highest sales?
# 20. What is the average discount by category?
# 21. Is there any relationship between discount and profit?
# 22. Which top 10 customers generated the highest sales?
# 23. Which top 10 products generated the highest revenue?
# 24. Which category receives the highest average discount?
# 25. Which ship mode gives the highest average profit?
# 26. What is the total quantity sold for each category?
# 27. Which state has the highest number of orders?
# 28. Find the top 5 cities by profit.
# 29. Which customer segment is the most profitable?
# 30. Create a dashboard showing Sales, Profit, Orders, Category-wise Sales, State-wise Sales, Monthly Trend, and Top 10 Customers.

# %%
df["Order ID"].nunique()
# Out:
# 5009

# %%
df["Customer ID"].nunique()
# Out:
# 793

# %%
df.groupby("State")["Sales"].sum().sort_values(ascending=False).head(1)
# Out:
# State
# California    457687.6315
# Name: Sales, dtype: float64

# %%
df.groupby("City")["Profit"].sum().sort_values(ascending=False).head(1)
# Out:
# City
# New York City    62036.9837
# Name: Profit, dtype: float64

# %%
df.groupby("Category")["Sales"].sum().sort_values(ascending=False)
# Out:
# Category
# Technology         836154.0330
# Furniture          741999.7953
# Office Supplies    719047.0320
# Name: Sales, dtype: float64

# %%
df.groupby("Sub-Category")["Profit"].sum().sort_values(ascending=False)
# Out:
# Sub-Category
# Copiers        55617.8249
# Phones         44515.7306
# Accessories    41936.6357
# Paper          34053.5693
# Binders        30221.7633
# Chairs         26590.1663
# Storage        21278.8264
# Appliances     18138.0054
# Furnishings    13059.1436
# Envelopes       6964.1767
# Art             6527.7870
# Labels          5546.2540
# Machines        3384.7569
# Fasteners        949.5182
# Supplies       -1189.0995
# Bookcases      -3472.5560
# Tables        -17725.4811
# Name: Profit, dtype: float64

# %%
df["Ship Mode"].value_counts()
# Out:
# Ship Mode
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: count, dtype: int64

# %%
df.groupby("Customer Name")["Order ID"].nunique().sort_values(ascending=False).head(1)
# Out:
# Customer Name
# Emily Phan    17
# Name: Order ID, dtype: int64

# %%
df.groupby("Segment")["Sales"].sum().sort_values(ascending=False)
# Out:
# Segment
# Consumer       1.161401e+06
# Corporate      7.061464e+05
# Home Office    4.296531e+05
# Name: Sales, dtype: float64

# %%
print("Total Sales:", df["Sales"].sum())
print("Total Profit:", df["Profit"].sum())
# Out:
# Total Sales: 2297200.8603
# Total Profit: 286397.0217

# %%
df.groupby("Region")["Profit"].sum().sort_values(ascending=False)
# Out:
# Region
# West       108418.4489
# East        91522.7800
# South       46749.4303
# Central     39706.3625
# Name: Profit, dtype: float64

# %%
df.groupby("Order ID")["Sales"].sum().mean()
# Out:
# np.float64(458.61466566180883)

# %%
df.groupby("Product Name")["Sales"].sum().sort_values(ascending=False).head(1)
# Out:
# Product Name
# Canon imageCLASS 2200 Advanced Copier    61599.824
# Name: Sales, dtype: float64

# %%
df.groupby("Product Name")["Profit"].sum().sort_values(ascending=False).head(1)
# Out:
# Product Name
# Canon imageCLASS 2200 Advanced Copier    25199.928
# Name: Profit, dtype: float64

# %%
df.groupby("State")["Profit"].sum().sort_values().head(1)
# Out:
# State
# Texas   -25729.3563
# Name: Profit, dtype: float64

# %%
df.groupby("Sub-Category")["Profit"].sum().sort_values().head(1)
# Out:
# Sub-Category
# Tables   -17725.4811
# Name: Profit, dtype: float64

# %%
df.groupby(df['Order Date'].dt.to_period('M'))['Sales'].sum()
# Out:
# Order Date
# 2014-01     14236.8950
# 2014-02      4519.8920
# 2014-03     55691.0090
# 2014-04     28295.3450
# 2014-05     23648.2870
# 2014-06     34595.1276
# 2014-07     33946.3930
# 2014-08     27909.4685
# 2014-09     81777.3508
# 2014-10     31453.3930
# 2014-11     78628.7167
# 2014-12     69545.6205
# 2015-01     18174.0756
# 2015-02     11951.4110
# 2015-03     38726.2520
# 2015-04     34195.2085
# 2015-05     30131.6865
# 2015-06     24797.2920
# 2015-07     28765.3250
# 2015-08     36898.3322
# 2015-09     64595.9180
# 2015-10     31404.9235
# 2015-11     75972.5635
# 2015-12     74919.5212
# 2016-01     18542.4910
# 2016-02     22978.8150
# 2016-03     51715.8750
# 2016-04     38750.0390
# 2016-05     56987.7280
# 2016-06     40344.5340
# 2016-07     39261.9630
# 2016-08     31115.3743
# 2016-09     73410.0249
# 2016-10     59687.7450
# 2016-11     79411.9658
# 2016-12     96999.0430
# 2017-01     43971.3740
# 2017-02     20301.1334
# 2017-03     58872.3528
# ...

# %%
df.groupby(df["Order Date"].dt.year)["Profit"].sum()
# Out:
# Order Date
# 2014    49543.9741
# 2015    61618.6037
# 2016    81795.1743
# 2017    93439.2696
# Name: Profit, dtype: float64

# %%
df.groupby(df["Order Date"].dt.month_name())["Sales"].sum().sort_values(ascending=False)
# Out:
# Order Date
# November     352461.0710
# December     325293.5035
# September    307649.9457
# March        205005.4888
# October      200322.9847
# August       159044.0630
# May          155028.8117
# June         152718.6793
# July         147238.0970
# April        137762.1286
# January       94924.8356
# February      59751.2514
# Name: Sales, dtype: float64

# %%
df.groupby("Category")["Discount"].mean()
# Out:
# Category
# Furniture          0.173923
# Office Supplies    0.157285
# Technology         0.132323
# Name: Discount, dtype: float64

# %%
print(df[["Discount", "Profit"]].corr())
# Out:
#           Discount    Profit
# Discount  1.000000 -0.219487
# Profit   -0.219487  1.000000
